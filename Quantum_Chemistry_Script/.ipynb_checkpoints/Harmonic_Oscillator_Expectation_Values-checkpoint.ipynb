# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Calculation of the Density Matrix

# %%
angfreq = 6.546*10**(12)
hbar = 6.62607004*10**(-34)/(2*np.pi)
mass = 1.6726*10**(27)
k_B = 1.38064852*10**(-23)

# %%
def energy(n):
    return (n+1/2)*hbar*angfreq

# %%
def density_matrix(T):
    Z = 0
    for k in list(range(50)):
        Z = Z + np.exp(-energy(k)/(k_B*T))
    matrix = np.zeros((50,50))
    for i in list(range(50)):
        matrix[i,i] = matrix[i,i] + 1/Z * np.exp(-energy(i)/(k_B*T))
    return matrix

# %%
g = 0
for j in range(50):
    g = g + density_matrix(300)[j,j]
print(g)
# Out:
# 1.0

# %%
print(density_matrix(300))
# Out:
# [[1.53554867e-01 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 1.29981438e-01 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 1.10026953e-01 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  ...
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 6.08552191e-05
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   5.15128502e-05 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 4.36047027e-05]]

# %%
def boltzmann(T):
    fig = plt.figure(figsize =(13 ,9))
    ax = fig.add_subplot(1,1,1)
    
    x = list(range(50))
    y = density_matrix(T)[x,x]
    ax.scatter(x, y, s=15, alpha=1.0)


    ax.set_title(r'$\mathrm{Boltzmann\;Distribution}$', fontsize=25)
    ax.set_xlabel(r'$\mathrm{Quantum}\;\mathrm{States}$', fontsize=23)
    ax.set_ylabel(r'$\mathrm{Probability}$', fontsize=23)

    plt.show()

# %%
print(boltzmann(300))
# Out:
# None

# %%
print(boltzmann(0.1))
# Out:
# None

# %% [markdown]
# ## Average Internal Energy and Classical Limit

# %%
def total_energy():
    matrix1 = np.zeros((50,50))
    for i in list(range(50)):
        matrix1[i,i] = matrix1[i,i] + (i+1/2)*angfreq*mass
    return matrix1

# %%
print(total_energy())
# Out:
# [[5.47441980e+39 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 1.64232594e+40 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 2.73720990e+40 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  ...
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 5.20069881e+41
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   5.31018721e+41 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 5.41967560e+41]]

# %%
def internal_energy():
    vec = []
    for T in [1+h*1 for h in list(range(50))]:
        f = 0
        matrix2 = np.matmul(density_matrix(T),total_energy())
        for i in list(range(len(matrix2))):
            f = f + matrix2[i,i]
        vec.append(f)
    return vec

# %%
print(internal_energy())
# Out:
# [5.4744198e+39, 5.474419800152064e+39, 5.474420432620274e+39, 5.474460603832209e+39, 5.474916910348533e+39, 5.477052249163795e+39, 5.483081738714074e+39, 5.495597213750928e+39, 5.516911944085904e+39, 5.548693794182822e+39, 5.591893758866217e+39, 5.646843866854813e+39, 5.713413452601938e+39, 5.791161609506906e+39, 5.879461122820493e+39, 5.977589526091e+39, 6.084791481779076e+39, 6.20031903518583e+39, 6.323455955700145e+39, 6.453531169057959e+39, 6.589924992077811e+39, 6.732070790653346e+39, 6.87945385059549e+39, 7.031608651937023e+39, 7.18811532039697e+39, 7.348595746335796e+39, 7.512709672399454e+39, 7.680150926786009e+39, 7.850643898705817e+39, 8.02394030157827e+39, 8.199816237871567e+39, 8.378069560542614e+39, 8.558517515290416e+39, 8.74099464232594e+39, 8.925350914125141e+39, 9.111450085388776e+39, 9.299168232350889e+39, 9.488392460126033e+39, 9.679019758625535e+39, 9.870955989499584e+39, 1.0064114988449398e+40, 1.0258417769033999e+40, 1.0453791815733118e+40, 1.0650170455508232e+40, 1.0847492298426322e+40, 1.1045700739084104e+40, 1.1244743511602713e+40, 1.144457229186921e+40, 1.1645142341493577e+40, 1.1846412188641146e+40]

# %%
def internal_energy_2(T):
    f = 0
    matrix2 = np.matmul(density_matrix(T),total_energy())
    for i in list(range(len(matrix2))):
        f = f + matrix2[i,i]
    return f

# %%
print(internal_energy_2(50))
# Out:
# 1.1846412188641146e+40

# %%
len(internal_energy())
# Out:
# 50

# %%
def energy_plot():
    fig = plt.figure(figsize =(13 ,9))
    ax = fig.add_subplot(1,1,1)
    
    x = np.linspace(1, 50, 50)
    y = internal_energy()
    ax.plot(x,y)
    
    ax.set_xlabel(r'$\mathrm{Temperature}$', fontsize=23)
    ax.set_ylabel(r'$\mathrm{Internal}\;\mathrm{Energy}$', fontsize=23)
    
    plt.show()

# %%
print(energy_plot())
# Out:
# None
